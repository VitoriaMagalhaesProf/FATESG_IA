# %%
import pandas as pd #biblioteca pandas - pd abreviação
import numpy as np #n foi utilizado ainda(sombriado)

# %%
u = pd.Series([9, 3, 5, 6, 8])
print(u) #
# Out:
# 0    9
# 1    3
# 2    5
# 3    6
# 4    8
# dtype: int64

# %%
v = pd.Series()
print(v)
# Out:
# Series([], dtype: object)

# %%
data = np.array([1, 3, 5, 7, 9])
v = pd.Series(data)
v
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
data = np.array(['a', 'b', 'c', 'd', 'e']) #indices=basicamente dar valor casa para os valores
v = pd.Series(data, index = [100, 101, 102, 103, 104]) 
print (v)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# 104    e
# dtype: str

# %%
dados = {'a': 0., 'b':1., 'c':2.} #indices e valores = números com virgula
v = pd.Series(dados)
v
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
idades = {'Vitória': 23, 'Gustavo': 24, 'Adriano': 30, 'Karem': 26, 'Melissa': 28}
i = pd.Series(idades) #passar indice e idade direto
i
# Out:
# Vitória    23
# Gustavo    24
# Adriano    30
# Karem      26
# Melissa    28
# dtype: int64

# %%
data = {'a': 0., 'b':1., 'c':2.} #mostrar o NaN = para mostrar erros em programações
i = pd.Series(data, index= ['b', 'c', 'd', 'a'])
i
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
dados = pd.Series(5, index=[0,1,2,3,4,5]) #independente do número o indice continuara o primeiro informado (5)
dados
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# 5    5
# dtype: int64

# %%
dados = pd.Series([1, 3, 5, 7, 9], index=['a', 'b', 'c', 'd', 'e'])
print(dados)
# Out:
# a    1
# b    3
# c    5
# d    7
# e    9
# dtype: int64

# %%
print('O primeiro elemento é o: ', dados['a'])
print('O terceiro elemento é o: ', dados['e'])
# Out:
# O primeiro elemento é o:  1
# O terceiro elemento é o:  9

# %%
dados = pd.Series([1, 2, 3, 4, 5]), index=['a', 'b', 'c', 'd', 'd', 'e'])

print (dados[[]'a', 'c', 'd']])
# Out:
#   Cell In[16], line 1
#     dados = pd.Series([1, 2, 3, 4, 5]), index=['a', 'b', 'c', 'd', 'd', 'e'])
#                                                                             ^
# SyntaxError: unmatched ')'
